# %%
# %load_ext autoreload

# %%
# %autoreload
import pha
from pha import strip_url_to_pattern
archive = pha.Archive.default_location()
print(archive)
# Out:
# <Archive at '/Users/ianbicking/src/personal-history-archive'>

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/ianbicking/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
histories = archive.sample_histories_with_page(10, unique_url=True, unique_domain=False)
print("Histories:", len(histories), "Domains:", len(set(h.domain for h in histories)))
print("Patterns:", [strip_url_to_pattern(h.url) for h in histories], [h.url for h in histories])
## Instead, to keep it stable:
histories = [archive.get_history(url) for url in [
    'https://blog.ungleich.ch/en-us/cms/blog/2017/12/10/the-importance-of-devuan/', 
    'https://www.massdrop.com/buy/seeed-kiwisdr-kit?1=1&utm_placement=22&referer=BVGTE5&mode=guest_open&utm_campaign=Automated%20Daily%20Promotional%202018-01-28&utm_source=SparkPost&utm_medium=email&utm_term=Daily%20Promotional&utm_content=1517140787784.573895132428519667601966',
    'http://update.mapeditor.org/snapshots-osx/', 
    'https://talkingpointsmemo.com/livewire/debbie-wesson-gibson-moore-scrapbook-graduation-card', 
    'https://i.imgur.com/mcGDM8b.gifv', 
    'https://docs.google.com/document/d/19kMWt4C5J2XAXrKvYUBYqz7Sy7D36zJp5u8lJwWWm8s/edit', 
    'https://github.com/mozilla-services/screenshots/issues?q=is%3Aopen+is%3Aissue+milestone%3A%22General+Release+57%22', 
    ]]
# Out:
# Histories: 10 Domains: 10
# Patterns: ['gfycat.com/C', 'docs.python.org/#/C/C', 'google.com/C', 'analytics.google.com/C/C', 'i.imgur.com/C', 'docs.google.com/C/C/#/C/C/C', 'massdrop.com/C/C', 'youtube.com/C', 'oauth.accounts.firefox.com/C/C', 'auth.mozilla.auth0.com/C'] ['https://gfycat.com/teemingtalkativehammerkop', 'https://docs.python.org/3/library/collections.abc.html', 'https://www.google.com/search?q=Van+Barnes&client=firefox-b-ab&source=lnms&tbm=isch&sa=X&ved=0ahUKEwiznKGa283XAhVB_4MKHYLYBd0Q_AUICigB&biw=1234&bih=681#imgrc=SVxZR1dI6wKtUM:', 'https://analytics.google.com/analytics/web/?authuser=1#report/visitors-overview/a49796218w101460360p105413474/', 'https://i.imgur.com/yfuJNk2.jpg', 'https://docs.google.com/document/u/0/d/1gq_OrvYBRYstJ0IbH1TiZ7ZpKbfslRefYUu3oGtXsbM/edit', 'https://www.massdrop.com/buy/seeed-kiwisdr-kit?1=1&utm_placement=22&referer=BVGTE5&mode=guest_open&utm_campaign=Automated%20Daily%20Promotional%202018-01-28&utm_source=SparkPost&utm_medium=email&utm_term=Daily%20Promotional&utm_content=1517140787784.573895132428519667601966', 'https://www.youtube.com/watch?v=dnp-8GrHOIk&start=86400', 'https://oauth.accounts.firefox.com/v1/authorization?client_id=749818d3f2e7857f&state=968e32d4e3588d730074ec7ce3b26d12&scope=profile:uid+profile:email+profile:display_name', 'https://auth.mozilla.auth0.com/login?client=smKTjsVVxUJDEkjIftOsP0bop2NWjysa&protocol=samlp&redirect_uri=https%3A%2F%2Fwww.google.com%2Fa%2Fmozilla.com%2Facs&SAMLRequest=fVLJTsMwEL0j8Q%2BR79mqIiGrCSqtKiqxRDTlwM11JqlbL8HjtMDX46Yg4NBKvvh5%2FJaZGd28KxnswKIwOiNplJAANDeV0E1GluUsvCY3%2BeXFCJmSLR13bq2f4a0DdIH%2FqZH2DxnprKaGoUCqmQKkjtPF%2BOGeDqKEttY4w40kwXyaEbnd8kbVrFlJpvlGKqHaLTObzXrFaiWg1bqWfFWR4OXH1uBga47YwVyjY9p5KEmvw2TgT5kM6VVKh8krCYpvpVuhjwnO2Vodi5DelWURFk%2BLsifYiQrso6%2FOSGNMIyHiRh3kC4Yodh6umUQgwRgRrPMGJ0Zjp8AuwO4Eh%2BXzfUbWzrVI43i%2F30e%2FNDGLlfkUUrLjjSPJ%2B9bSPp3909Pz3tmPNslPsY%2FiP8T59wAPuebTwkjBP4KxlGY%2FscCcD%2BVs5zPNjFXMndZOo7RHRBXWfSntNLbARS3ATyzOj6r%2FN8Xvzxc%3D&RelayState=https%3A%2F%2Faccounts.google.com%2FCheckCookie%3Fcontinue%3Dhttps%253A%252F%252Fmail.google.com%252Fmail%252Fu%252F1%252F%26service%3Dmail%26ss%3D1%26scc%3D1%26rm%3Dfalse%26osid%3D1&state=kLwYzboF6Aa5IV7GPYcHXZyqNPy6sCHj']

# %%
# %autoreload
from pha import summarytools

for h in histories:
    sumy_summary = summarytools.sumy_summary(h.page)
    summary_readable = h.page.readable_text and summarytools.textteaser_summary(h.page)
    summary = summarytools.textteaser_summary(h.page, try_readable=False)
    h.page.display_page(readable=True)
    print("Sumy summary:", summarytools.normalize_sentences(sumy_summary))
    print()
    if summary_readable:
        print(
            "Readable summary:", 
            summarytools.normalize_sentences(summary_readable))
        print()
    print("Normal summary:", summarytools.normalize_sentences(summary))
# Out:
#         <div>
#           <div>
#             <strong>Mozilla Slack</strong> <a href="https://mozilla.slack.com/messages/C4DPE7X2A" target=_blank>mozilla.slack.com</a>
#           </div>
#           <iframe style="width: 100%; height: 12em; overflow: scroll" scrolling="yes" src="data:text/html;base64,..."></iframe>
#         </div>
# Sumy summary: Each participant will get their own cursor, along with the ability to type, edit, scroll, and click through the contents of the shared screen.Note: You'll need the latest version of our Mac desktop app (directly downloaded from our website) .  This time around we’re highlighting a few small-yet-mighty features that keep your work moving — like the ability to find channels you’ve renamed, view your top search results, and preview GIFs in Giphy.  March 16, 2017 Channel names can now include a much broader set of characters and accents, so you can easily manage and organize conversations in your primary language.  It is video, after all…) For the best experience, make sure you're on the latest versions of our Mac and Windows desktop apps (or use Google Chrome).  November 15, 2016 In case you missed some recent updates to Slack, we’ve summed them up for you in a lovely little list on our blog, because you deserve to know all the things!
#
# Readable summary: We’ve localized our product, website, and support so you can tailor Slack to work the way you do.  Now there’s a new way to bring any email (and its attachments) into Slack.  No matter what you’re up to or where you’re going — you can now set your status in Slack so teammates know.  Your workspace has joined Slack’s Video Calls beta, so you can now make video calls right in Slack.  As of today, you can also set reminders for any message in Slack, to remind yourself to come back to it.
#
# Normal summary: Enable notifications • Ask me next time • Never ask again on this computer Download the Slack Mac app for greater control over your notifications.  You can add a star to messages, files, snippets, posts, comments … pretty much anything in Slack.  Read more on the blog September 6, 2017 Bring important emails into Slack Something noteworthy take place over email?  Learn more on our blog May 16, 2017 Now presenting... screen sharing in Slack You can now share your screen directly from Slack.  Learn more on our blog June 21, 2016 Do more of your work from Slack We’ve built a new way to interact with the apps you use in Slack.
#         <div>
#           <div>
#             <strong>Discord</strong> <a href="https://discordapp.com/channels/348060277989965844/392036355015966741" target=_blank>discordapp.com</a>
#           </div>
#           <iframe style="width: 100%; height: 12em; overflow: scroll" scrolling="yes" src="data:text/html;base64,..."></iframe>
#         </div>
# Sumy summary: how do i turn this thing on
#
# Normal summary: 0 Online + Download Apps New Unreads New Unreads Drag &amp; Drop You can add comments before uploading.  Hold shift to upload directly.  how do i turn this thing on submitted by @asdfghjklibbyx Connecting Connection problems?  Let us know!  Tweet Us Server Status
#         <div>
#           <div>
#             <strong>ungleich Blog - The importance of Devuan</strong> <a href="https://blog.ungleich.ch/en-us/cms/blog/2017/12/10/the-importance-of-devuan/" target=_blank>blog.ungleich.ch</a>
#           </div>
#           <iframe style="width: 100%; height: 12em; overflow: scroll" scrolling="yes" src="data:text/html;base64,..."></iframe>
#         </div>
# Sumy summary: But first, let me put some warning out here: Dear Devuan friends, while I honor your work, I also have to be very honest with you: in theory, you should not have done this.  Think of it in real world terms: You are in a super market and there is a new variant of a product that you used to buy (let it be razor blades, toilet paper rolls, whiskey, you name it).  Systemd developers split the community over a tiny detail that decreases stability significantly and increases complexity for not much real value.  We are a small team at ungleich and we simply don't have the time to fix problems caused by systemd on a daily basis.  Think about it not in a few repeating systemd bugs or about the insecurity caused by a huge, monolithic piece of software running with root privileges.
#
# Readable summary: A perfect time to write about the importance of Devuan to us, but also for the future of Linux.  Looking at creating Devuan, which means splitting of Debian, economically, you caused approximately infinite cost.  Yes, dear Devuan community, you have to admit it, you caused this cost for every potential Linux user.  So, coming back to the original title of this essay: the importance of Devuan.  Thus I would like to urge every reader who made it until here: Do what we do: Support Devuan.
#
# Normal summary: Toggle navigation home Hack4Glarus The importance of Devuan A Sunday morning essay Posted on Dec. 10, 2017 Good morning, my name is Nico Schottelius, I am the CEO of ungleich glarus ltd .  A perfect time to write about the importance of Devuan to us, but also for the future of Linux.  Yes, dear Devuan community, you have to admit it, you caused this cost for every potential Linux user.  So, coming back to the original title of this essay: the importance of Devuan.  Thus I would like to urge every reader who made it until here: Do what we do: Support Devuan.
#         <div>
#           <div>
#             <strong>Index of /snapshots-osx/</strong> <a href="http://update.mapeditor.org/snapshots-osx/" target=_blank>update.mapeditor.org</a>
#           </div>
#           <iframe style="width: 100%; height: 12em; overflow: scroll" scrolling="yes" src="data:text/html;base64,..."></iframe>
#         </div>
# Sumy summary:
#
# Readable summary:  ../ tiled-2016.05.01.dmg 01-May-2016 15:14 17M tiled-2016.05.22.dmg 22-May-2016 12:07 18M tiled-2016.05.30.dmg 30-May-2016 21:07 18M tiled-2016.06.05.dmg 05-Jun-2016 16:06 20M tiled-2016.06.12.dmg 12-Jun-2016 15:07 20M tiled-2016.07.03.dmg 03-Jul-2016 17:07 20M tiled-2016.07.22.dmg 22-Jul-2016 10:07 20M tiled-2016.07.25.dmg 25-Jul-2016 16:07 20M tiled-2016.08.12.dmg 12-Aug-2016 16:07 20M tiled-2016.08.15.dmg 15-Aug-2016 21:07 20M tiled-2016.08.26.dmg 26
# Normal summary: Ian My Account Search Maps YouTube Play News Gmail Drive Calendar Google+ Translate Photos More Shopping Wallet Finance Docs Books Blogger Contacts Hangouts Keep Classroom Even more from Google Change Ian Bicking ianbicking@gmail.com Google+ Profile – Privacy My Account Ian Bicking ianbicking@gmail.com (default) Ian Bicking ibicking@mozilla.com All your Brand Accounts » Add account Sign out Directions Find a place Lite Mode Terms 20 m You're in Lite mode Switch back to full Maps Search this area Options Avoid Highways Avoid Toll Roads Avoid Ferries Done Cancel Directions from here Directions to here What's here?  Map Trails Dedicated lanes Bicycle-friendly roads Dirt/unpaved trails Live traffic Fast Slow
#         <div>
#           <div>
#             <strong>WaPo: Roy Moore Accuser Shares New Details About Their Relationship – Talking Points Memo</strong> <a href="https://talkingpointsmemo.com/livewire/debbie-wesson-gibson-moore-scrapbook-graduation-card" target=_blank>talkingpointsmemo.com</a>
#           </div>
#           <iframe style="width: 100%; height: 12em; overflow: scroll" scrolling="yes" src="data:text/html;base64,..."></iframe>
#         </div>
# Sumy summary: In a Nov. 10 interview with Sean Hannity — before he began claiming to not know any of the women alleging he pursued them when they were teenagers — Moore said he remembered Gibson.  Gibson had told the Post, for the paper’s Nov. 9 report, that she had dated Moore as a 17-year-old high school student in 1981, when he was a 34-year-old assistant district attorney.  The handwriting in Gibson’s scrapbook appeared to be the same as that of a yearbook inscription, also allegedly from Moore, presented by Nelson and her attorney, Gloria Allred, in a press conference.  The Post reported that representatives of Moore’s campaign had not responded to requests for comment on its story Monday.  The special election to fill Attorney General Jeff Sessions’ Senate seat, which is currently held by interim Sen. Luther Strange (R-AL), will take place on Dec. 12.
#
# Readable summary: I know that you’ll be a success in anything you do.  Roy.”The scrapbook presented more proof elsewhere, including Gibson’s record at the time of receiving “$10, card” from “Roy S. Moore,” and her reflection on a date with Moore under a section titled “the best times.” “Wednesday night, 3-4-81.  Roy S. Moore and I went out for the first time,” Gibson had written.  Days later, Beverly Young Nelson alleged Moore sexually assaulted her when she was 16.  The Post reported that representatives of Moore’s campaign had not responded to requests for comment on its story Monday.
#
# Normal summary: After Debbie Wesson Gibson saw a Nov. 27 video of Moore saying “ I do not know any of these women,” the Post reported , she found a graduation card from Moore in a scrapbook in her attic.  “Happy graduation Debbie,” Moore appears to have written.  Roy.” The scrapbook presented more proof elsewhere, including Gibson’s record at the time of receiving “$10, card” from “Roy S. Moore,” and her reflection on a date with Moore under a section titled “the best times.” “Wednesday night, 3-4-81.  Roy S. Moore and I went out for the first time,” Gibson had written.  The Post reported that representatives of Moore’s campaign had not responded to requests for comment on its story Monday.
#         <div>
#           <div>
#             <strong>Play stupid games...</strong> <a href="https://i.imgur.com/mcGDM8b.gifv" target=_blank>i.imgur.com</a>
#           </div>
#           <iframe style="width: 100%; height: 12em; overflow: scroll" scrolling="yes" src="data:text/html;base64,..."></iframe>
#         </div>
# Sumy summary:
#
# Normal summary: Imgur download
#         <div>
#           <div>
#             <strong>GitHub and Relman - Google Docs</strong> <a href="https://docs.google.com/document/d/19kMWt4C5J2XAXrKvYUBYqz7Sy7D36zJp5u8lJwWWm8s/edit" target=_blank>docs.google.com</a>
#           </div>
#           <iframe style="width: 100%; height: 12em; overflow: scroll" scrolling="yes" src="data:text/html;base64,..."></iframe>
#         </div>
# Sumy summary: The code we ship to our users in desktop FFx needs to be tighter  GitHub was more friendly to working in modern Web development tools  Creating a project on GitHub is a self-service operation:  CK: Balancing innovation vs risk management  1.Bugs in GH are hard to track regressions
#
# Readable summary: GitHub outcomes and benefits Consistency and managing risk around it The code we ship to our users in desktop FFx needs to be tighter What’s the benefit to the org, not the benefit to the team Moving pieces out of BMO/MC externalizes risk For devtools, we want to be on GitHub because that is where contributors are GitHub was more friendly to working in modern Web development tools git clone; npm start; git commit; The best web development tools should be built by web developers and web developers are on Quality and Developer Ergonomics 1-2 people working on BMO Hundreds working on GitHub Integration with Travis and Circle CI Integration with probot and customize workflows Creating a project on GitHub is a self-service operation: Someone starting a new project doesn’t have to introduce externalities for a project that may or may not end up on Firefox -Hears the value of GitHub, etc.  but can’t push additional workload on to release -It is helpful to let teams design their own workflows -Set of milestones that are consistent CK: Balancing innovation vs risk management Github innovation doesn’t mean we can’t get it elsewhere/Bugzilla 1.Bugs in GH are hard to track regressions a.See the quality of the release
#
# Normal summary: Some Word features can't be displayed in Google Docs and will be dropped if you make changes View details ibicking@mozilla.com This account is managed by mozilla.com .  Bugs in GH are hard to track regressions a.  See the quality of the release Outline Headings that you add to the document will appear here.  Learn more « Close preview Print Explore Explore Cloud Search Web Images Create rich documents To see content tailored to your document, try searching above.  Learn more Can't load Explore content Retry Dictionary Search dictionary Use the dictionary to find definitions or synonyms for a word.
#         <div>
#           <div>
#             <strong>Issues · mozilla-services/screenshots</strong> <a href="https://github.com/mozilla-services/screenshots/issues?q=is%3Aopen+is%3Aissue+milestone%3A%22General+Release+57%22" target=_blank>github.com</a>
#           </div>
#           <iframe style="width: 100%; height: 12em; overflow: scroll" scrolling="yes" src="data:text/html;base64,..."></iframe>
#         </div>
# Sumy summary: You signed in with another tab or window.  Reload to refresh your session.You signed out in another tab or window.  Reload to refresh your session.
#
# Normal summary: Stop ignoring Unstar 370 Star 370 Fork Where should we fork this repository?  Use the links above to find what you’re looking for, or try a new search query .  The Filters menu is also super helpful for quickly finding issues most relevant to you.  Type g i on any issue or pull request to go back to the issue listing page.  Terms Privacy Security Status Help Contact GitHub API Training Shop Blog About You can't perform that action at this time.
#         <div>
#           <div>
#             <strong>reddit: the front page of the internet</strong> <a href="https://www.reddit.com/" target=_blank>reddit.com</a>
#           </div>
#           <iframe style="width: 100%; height: 12em; overflow: scroll" scrolling="yes" src="data:text/html;base64,..."></iframe>
#         </div>
# Sumy summary:
#
# Readable summary: reddit gold gives you extra features and helps keep our servers running.  We believe the more reddit can be user-supported, the freer we will be to make reddit the best it can be.Buy gold for yourself to gain access to extra features and special benefits.  A month of gold pays for 231.26 minutes of reddit server time!Give gold to thank exemplary people and encourage them to post more.This daily goal updates every 10 minutes and is reset at midnight Pacific Time (8 hours, 19 minutes from now).Yesterday's reddit gold goal
#
# Normal summary: Submit a new link Submit a new text post Create your own subreddit ...do it for the children.  daily reddit gold goal 62% help support reddit reddit gold gives you extra features and helps keep our servers running.  We believe the more reddit can be user-supported, the freer we will be to make reddit the best it can be.  This daily goal updates every 10 minutes and is reset at midnight Pacific Time (8 hours, 19 minutes from now).  ( i.redd.it ) submitted 5 hours ago by UncleUdink [vw] to r/funny 600 comments share save hide report crosspost 2 23.9k 23.9k 23.9k Hi.
