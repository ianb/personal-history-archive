# %%
# %load_ext autoreload

# %%
# %autoreload
import pha
import pha.htmltools
from pha.search import create_index, search
archive = pha.Archive.default_location()
print(archive)
# Out:
# <Archive at '/Users/ianbicking/src/personal-history-archive'>

# %%
# create_index recreates the entire index if purge is True (which is the default)
# This can take a while to run...
print(create_index(archive, purge=False), "pages indexed")
# Out:
# 13049 pages indexed

# %%
results = search(archive, "roundabout")
print(results)
results[0].page.display_page()
# Out:
# <SearchResult[] 'roundabout': 4 results>
#         <div>
#           <div>
#             <strong>round about sign is painted boss... : NotMyJob</strong> <a href="https://www.reddit.com/r/NotMyJob/comments/7ummh7/round_about_sign_is_painted_boss/" target=_blank>reddit.com</a>
#           </div>
#           <iframe style="width: 100%; height: 12em; overflow: scroll" scrolling="yes" src="data:text/html;base64,..."></iframe>
#         </div>
